# %%
import pandas as pd
import numpy as np

# %%
filepath="LPD.csv"
df=pd.read_csv(filepath,encoding_errors='ignore')

# %%
xf=df
xf
# Out:
#        Age of the patient Gender of the patient  Total Bilirubin  \
# 0                    65.0                Female              0.7
# 1                    62.0                  Male             10.9
# 2                    62.0                  Male              7.3
# 3                    58.0                  Male              1.0
# 4                    72.0                  Male              3.9
# ...                   ...                   ...              ...
# 30686                50.0                  Male              2.2
# 30687                55.0                  Male              2.9
# 30688                54.0                  Male              6.8
# 30689                48.0                Female              1.9
# 30690                30.0                  Male              3.1
#
#        Direct Bilirubin  Alkphos Alkaline Phosphotase  \
# 0                   0.1                         187.0
# 1                   5.5                         699.0
# 2                   4.1                         490.0
# 3                   0.4                         182.0
# 4                   2.0                         195.0
# ...                 ...                           ...
# 30686               1.0                         610.0
# 30687               1.3                         482.0
# 30688               3.0                         542.0
# 30689               1.0                         231.0
# 30690               1.6                         253.0
#
#        Sgpt Alamine Aminotransferase  Sgot Aspartate Aminotransferase  \
# 0                               16.0                             18.0
# 1                               64.0                            100.0
# 2                               60.0                             68.0
# 3                               14.0                             20.0
# 4                               27.0                             59.0
# ...                              ...                              ...
# 30686                           17.0                             28.0
# 30687                           22.0                             34.0
# 30688                          116.0                             66.0
# 30689                           16.0                             55.0
# 30690                           80.0                            406.0
#
#        Total Protiens  ALB Albumin  A/G Ratio Albumin and Globulin Ratio  \
# 0                 6.8          3.3                                  0.90
# 1                 7.5          3.2                                  0.74
# 2                 7.0          3.3                                  0.89
# 3                 6.8          3.4                                  1.00
# 4                 7.3          2.4                                  0.40
# ...               ...          ...                                   ...
# 30686             7.3          2.6                                  0.55
# 30687             7.0          2.4                                  0.50
# 30688             6.4          3.1                                  0.90
# 30689             4.3          1.6                                  0.60
# 30690             6.8          3.9                                  1.30
#
#        Result
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 30686       1
# 30687       1
# 30688       1
# 30689       1
# 30690       1
#
# [30691 rows x 11 columns]

# %%
xf=xf.rename(columns={'Age of the patient':'age','Gender of the patient':'gender',
                  'Total Bilirubin':'tb','Direct Bilirubin':'db','Alkphos Alkaline Phosphotase':'aap',
                  'Sgpt Alamine Aminotransferase':'sgpt','Sgot Aspartate Aminotransferase':'sgot',
                  'Total Protiens':'tp','ALB Albumin':'alb','A/G Ratio Albumin and Globulin Ratio':'a/g_ratio',
                  'Result':'result'})

# %%
xf
# Out:
#         age  gender    tb   db    aap   sgpt   sgot   tp  alb  a/g_ratio  \
# 0      65.0  Female   0.7  0.1  187.0   16.0   18.0  6.8  3.3       0.90
# 1      62.0    Male  10.9  5.5  699.0   64.0  100.0  7.5  3.2       0.74
# 2      62.0    Male   7.3  4.1  490.0   60.0   68.0  7.0  3.3       0.89
# 3      58.0    Male   1.0  0.4  182.0   14.0   20.0  6.8  3.4       1.00
# 4      72.0    Male   3.9  2.0  195.0   27.0   59.0  7.3  2.4       0.40
# ...     ...     ...   ...  ...    ...    ...    ...  ...  ...        ...
# 30686  50.0    Male   2.2  1.0  610.0   17.0   28.0  7.3  2.6       0.55
# 30687  55.0    Male   2.9  1.3  482.0   22.0   34.0  7.0  2.4       0.50
# 30688  54.0    Male   6.8  3.0  542.0  116.0   66.0  6.4  3.1       0.90
# 30689  48.0  Female   1.9  1.0  231.0   16.0   55.0  4.3  1.6       0.60
# 30690  30.0    Male   3.1  1.6  253.0   80.0  406.0  6.8  3.9       1.30
#
#        result
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 30686       1
# 30687       1
# 30688       1
# 30689       1
# 30690       1
#
# [30691 rows x 11 columns]

# %%
xf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30691 entries, 0 to 30690
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        30689 non-null  float64
#  1   gender     29789 non-null  object
#  2   tb         30043 non-null  float64
#  3   db         30130 non-null  float64
#  4   aap        29895 non-null  float64
#  5   sgpt       30153 non-null  float64
#  6   sgot       30229 non-null  float64
#  7   tp         30228 non-null  float64
#  8   alb        30197 non-null  float64
#  9   a/g_ratio  30132 non-null  float64
#  10  result     30691 non-null  int64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 2.6+ MB

# %%
newxf=xf.dropna() # removing null values

# %%
newxf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27158 entries, 0 to 30690
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        27158 non-null  float64
#  1   gender     27158 non-null  object
#  2   tb         27158 non-null  float64
#  3   db         27158 non-null  float64
#  4   aap        27158 non-null  float64
#  5   sgpt       27158 non-null  float64
#  6   sgot       27158 non-null  float64
#  7   tp         27158 non-null  float64
#  8   alb        27158 non-null  float64
#  9   a/g_ratio  27158 non-null  float64
#  10  result     27158 non-null  int64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 2.5+ MB

# %%
newxf.to_csv('lpd_not_null.csv',index=False)

# %%
newxf
# Out:
#         age  gender    tb   db    aap   sgpt   sgot   tp  alb  a/g_ratio  \
# 0      65.0  Female   0.7  0.1  187.0   16.0   18.0  6.8  3.3       0.90
# 1      62.0    Male  10.9  5.5  699.0   64.0  100.0  7.5  3.2       0.74
# 2      62.0    Male   7.3  4.1  490.0   60.0   68.0  7.0  3.3       0.89
# 3      58.0    Male   1.0  0.4  182.0   14.0   20.0  6.8  3.4       1.00
# 4      72.0    Male   3.9  2.0  195.0   27.0   59.0  7.3  2.4       0.40
# ...     ...     ...   ...  ...    ...    ...    ...  ...  ...        ...
# 30686  50.0    Male   2.2  1.0  610.0   17.0   28.0  7.3  2.6       0.55
# 30687  55.0    Male   2.9  1.3  482.0   22.0   34.0  7.0  2.4       0.50
# 30688  54.0    Male   6.8  3.0  542.0  116.0   66.0  6.4  3.1       0.90
# 30689  48.0  Female   1.9  1.0  231.0   16.0   55.0  4.3  1.6       0.60
# 30690  30.0    Male   3.1  1.6  253.0   80.0  406.0  6.8  3.9       1.30
#
#        result
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 30686       1
# 30687       1
# 30688       1
# 30689       1
# 30690       1
#
# [27158 rows x 11 columns]
